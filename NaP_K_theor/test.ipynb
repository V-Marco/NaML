# %%
import sys
sys.path.append("../")

import numpy as np
import matplotlib.pyplot as plt

from simple_models import NaP_Kdr
from voltage_current import CurrentInjection

# %%
model = NaP_Kdr(V_init = -60, n_init = 0.1)
V = model.simulate(CurrentInjection.ramp(0, 1, 100, 1000))
plt.plot(V)

# %%
np.where(V > -20)[0]
# Out:
# array([517, 520, 523, 526, 529, 532, 545, 548, 551, 554, 557, 570, 573,
#        576, 579, 582, 598, 601, 604, 612, 615, 623, 626, 629, 637, 640,
#        643, 651, 654, 662, 665, 668, 676, 679, 682, 690, 693, 701, 704,
#        709, 714, 719, 724, 729, 734, 739, 744, 749, 752, 757, 762, 767,
#        772, 777, 782, 787, 792, 797, 800, 802, 807, 809, 816, 823, 830,
#        837, 844, 846, 851, 853, 858, 860, 867, 874, 881, 888, 890, 895,
#        897, 904, 906, 908, 919, 921, 923, 932, 934, 936, 938, 947, 949,
#        951, 962, 964, 966, 977, 979, 981, 992, 994, 996])

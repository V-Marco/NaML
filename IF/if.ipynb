# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import torch

from trace import generate_current_inj_matrix
from network import train

# %%
sim_time_ms = 5000
N_exc_syn = 80
N_inh_syn = 20
N_syn = N_exc_syn + N_inh_syn
exc_w = 1.0
inh_w = -1.0
R = 2

V_peak = -60
V_reset = -75

win_size = 80

# %%
np.random.seed(123)
exc_CI = exc_w * generate_current_inj_matrix(3, N_exc_syn, sim_time_ms)
inh_CI = inh_w * generate_current_inj_matrix(3, N_inh_syn, sim_time_ms)

# %%
exc_CI.shape
# Out:
# (80, 5000)

# %%
plt.plot(exc_CI[0, :1000])

# %%
class IF:
    
    def __init__(self, V_peak, V_reset) -> None:
        self.V_peak = V_peak
        self.V_reset = V_reset
        self.V = V_reset
    
    def update_voltage(self, I_t):
        raise NotImplementedError
    
    def simulate(self, I):
        V_out = [self.V]
        spike_times = []
        T = len(I)

        was_peak = False

        for t in range(T):
            if was_peak:
                V_out.append(self.V)
                was_peak = False
                continue
            self.update_voltage(I[t])
            if self.V >= self.V_peak:
                V_out.append(self.V_peak)
                spike_times.append(t)
                self.V = self.V_reset
                was_peak = True
            else:
                V_out.append(self.V)
        
        return np.array(V_out[1:]), np.array(spike_times)

# %%
class QuadraticIF(IF):

    def update_voltage(self, I_t):
        self.V += I_t + self.V ** 2 # wrong

class LeakyIF(IF):

    def update_voltage(self, I_t):
        self.V = self.V + I_t - (self.V - self.V_reset) / R

# %%
lif = LeakyIF(V_peak = V_peak, V_reset = V_reset)

I_input = np.vstack((exc_CI, inh_CI)).sum(axis = 0)

V_out, spike_times = lif.simulate(I = I_input)
plt.plot(V_out)

# %%
spike_times
# Out:
# array([ 608,  612,  881,  886,  890, 1040, 1051, 1056, 1061, 1065, 1070,
#        1091, 1636, 1643, 1933, 1983, 1988, 1992, 2009, 2015, 2019, 2041,
#        2090, 2095, 2803, 2813, 2822, 2836, 3250, 3277, 3280, 3284, 3288,
#        3291, 3295, 3299, 3344, 3353, 3357, 3525, 3905, 3961, 4092, 4096,
#        4101, 4128, 4287, 4291, 4298, 4375])

# %%
def generate_dataset(size):

    I_input = np.zeros((size, N_syn, sim_time_ms))
    V_ouput = np.zeros((size, sim_time_ms))
    spikes_out = np.zeros((size, sim_time_ms))

    for i in tqdm(range(size)):
        np.random.seed(np.random.randint(50, 450))
        exc_CI = exc_w * generate_current_inj_matrix(3, N_exc_syn, sim_time_ms)
        inh_CI = inh_w * generate_current_inj_matrix(3, N_inh_syn, sim_time_ms)
        
        CI = np.vstack((exc_CI, inh_CI))
        I_input[i] = CI

        lif = LeakyIF(V_peak = V_peak, V_reset = V_reset)
        V_out, spikes = lif.simulate(CI.sum(axis = 0))
        V_ouput[i] = V_out.flatten()
        if len(spikes) > 0:
            spikes_out[i, spikes] = 1
    
    return I_input, V_ouput, spikes_out

# %%
I_input, V_ouput, spikes_out = generate_dataset(1)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.26it/s]

# %%
I_input.shape
# Out:
# (1, 100, 5000)

# %%
V_ouput.shape
# Out:
# (1, 5000)

# %%
spikes_out.shape
# Out:
# (1, 5000)

# %%
class IFDNN(torch.nn.Module):

    def __init__(self, N_syn, win_size):
        super().__init__()
        self.win_size = win_size
        self.conv = torch.nn.Conv1d(in_channels = N_syn, out_channels = 1, kernel_size = self.win_size, padding = "valid")
        self.spike_conv = torch.nn.Conv1d(in_channels = 1, out_channels = 1, kernel_size = 1, padding = "valid")
        self.v_conv = torch.nn.Conv1d(in_channels = 1, out_channels = 1, kernel_size = 1, padding = "valid")

    def forward(self, I_input):
        # Causal padding, so that the kernel uses [... t-1] to predict [t]
        I_input = torch.nn.functional.pad(I_input, (self.win_size - 1, 0))
        out = self.conv(I_input)

        spike_out = self.spike_conv(out)
        spike_out = torch.nn.functional.logsigmoid(spike_out)

        v_out = self.v_conv(out)

        return v_out, spike_out
    
model = IFDNN(N_syn = N_syn, win_size = win_size)

# %%
# https://discuss.pytorch.org/t/how-do-i-check-the-number-of-parameters-of-a-model/4325/8
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
count_parameters(model)
# Out:
# 8005

# %%
all_train_loss = []
all_test_loss = []

model = IFDNN(N_syn = N_syn, win_size = win_size)
I_input_test, V_ouput_test, spike_times_test = generate_dataset(32)
# Out:
# 100%|██████████| 32/32 [00:13<00:00,  2.45it/s]

# %%
for batch_num in range(10):

    I_input_train, V_ouput_train, spike_times_train = generate_dataset(32)

    train_loss_history, test_loss_history = train(
        num_epoch = 15,
        model = model,
        device_name = "cpu",
        lr = 0.0001, # 0.0003
        I_train = I_input_train,
        V_train = V_ouput_train,
        spike_times_train = spike_times_train,
        I_test = I_input_test,
        V_test = V_ouput_test,
        spike_times_test = spike_times_test,
        sim_time_ms = sim_time_ms
    )

    all_train_loss.extend(train_loss_history)
    all_test_loss.extend(test_loss_history)
# Out:
# 100%|██████████| 32/32 [00:13<00:00,  2.45it/s]
# [Epoch 0]:
#               train_loss = 8312.8779296875,
#               test_MSE = 4653.646484375,
#               test_BCE = 3560.997802734375,
#               test_loss = 8214.64453125,
#               test_acc = 0.99223125
#               test_AUC = 0.5215743231415706
# [Epoch 1]:
#               train_loss = 8217.353515625,
#               test_MSE = 4647.244140625,
#               test_BCE = 3476.518798828125,
#               test_loss = 8123.7626953125,
#               test_acc = 0.99223125
#               test_AUC = 0.5358913307759657
# [Epoch 2]:
#               train_loss = 8123.45751953125,
#               test_MSE = 4640.8505859375,
#               test_BCE = 3393.54638671875,
#               test_loss = 8034.39697265625,
#               test_acc = 0.99223125
#               test_AUC = 0.5493274934352608
# [Epoch 3]:
#               train_loss = 8031.19921875,
#               test_MSE = 4634.4677734375,
#               test_BCE = 3312.0869140625,
#               test_loss = 7946.5546875,
#               test_acc = 0.99223125
#               test_AUC = 0.5616210556638798
# [Epoch 4]:
#               train_loss = 7940.580078125,
#               test_MSE = 4628.0966796875,
#               test_BCE = 3232.144775390625,
#               test_loss = 7860.2412109375,
#               test_acc = 0.99223125
#               test_AUC = 0.5727916439901212
# [Epoch 5]:
#               train_loss = 7851.63720703125,
#               test_MSE = 4621.74072265625,
#               test_BCE = 3153.763427734375,
#               test_loss = 7775.50390625,
#               test_acc = 0.99223125
#               test_AUC = 0.5829145998571738
# [Epoch 6]:
#               train_loss = 7764.375,
#               test_MSE = 4615.4013671875,
#               test_BCE = 3076.94921875,
#               test_loss = 7692.3505859375,
#               test_acc = 0.99223125
#               test_AUC = 0.5919942129258187
# [Epoch 7]:
#               train_loss = 7678.80322265625,
#               test_MSE = 4609.080078125,
#               test_BCE = 3001.710693359375,
#               test_loss = 7610.791015625,
#               test_acc = 0.99223125
#               test_AUC = 0.600128762795801
# [Epoch 8]:
#               train_loss = 7594.9609375,
#               test_MSE = 4602.77978515625,
#               test_BCE = 2928.061279296875,
#               test_loss = 7530.8408203125,
#               test_acc = 0.99223125
#               test_AUC = 0.6073952201199269
# [Epoch 9]:
#               train_loss = 7512.8388671875,
#               test_MSE = 4596.5009765625,
#               test_BCE = 2856.00537109375,
#               test_loss = 7452.50634765625,
#               test_acc = 0.99223125
#               test_AUC = 0.6138524315441718
# [Epoch 10]:
#               train_loss = 7432.4453125,
#               test_MSE = 4590.2490234375,
#               test_BCE = 2785.55224609375,
#               test_loss = 7375.80126953125,
#               test_acc = 0.99223125
#               test_AUC = 0.619564610224572
# [Epoch 11]:
#               train_loss = 7353.7880859375,
#               test_MSE = 4584.021484375,
#               test_BCE = 2716.703857421875,
#               test_loss = 7300.7255859375,
#               test_acc = 0.99223125
#               test_AUC = 0.6245667829010177
# [Epoch 12]:
#               train_loss = 7276.8818359375,
#               test_MSE = 4577.82373046875,
#               test_BCE = 2649.455078125,
#               test_loss = 7227.27880859375,
#               test_acc = 0.99223125
#               test_AUC = 0.6289620483905054
# [Epoch 13]:
#               train_loss = 7201.7099609375,
#               test_MSE = 4571.65576171875,
#               test_BCE = 2583.80712890625,
#               test_loss = 7155.462890625,
#               test_acc = 0.99223125
#               test_AUC = 0.6328630273914325
# [Epoch 14]:
#               train_loss = 7128.2763671875,
#               test_MSE = 4565.5205078125,
#               test_BCE = 2519.754638671875,
#               test_loss = 7085.275390625,
#               test_acc = 0.99223125
#               test_AUC = 0.636280607483466
#  25%|██▌       | 8/32 [00:03<00:11,  2.14it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 for batch_num in range(10):
# ----> 3     I_input_train, V_ouput_train, spike_times_train = generate_dataset(32)
#       5     train_loss_history, test_loss_history = train(
#       6         num_epoch = 15,
#       7         model = model,
#    (...)
#      16         sim_time_ms = sim_time_ms
#      17     )
#      19     all_train_loss.extend(train_loss_history)
#
# Cell In[9], line 9, in generate_dataset(size)
#       7 for i in tqdm(range(size)):
#       8     np.random.seed(np.random.randint(50, 450))
# ----> 9     exc_CI = exc_w * generate_current_inj_matrix(3, N_exc_syn, sim_time_ms)
#      10     inh_CI = inh_w * generate_current_inj_matrix(3, N_inh_syn, sim_time_ms)
#      12     CI = np.vstack((exc_CI, inh_CI))
#
# File ~/segev/trace.py:31, in generate_current_inj_matrix(mfr, N_syn, T)
#      29 matrix = np.zeros((N_syn, T))
#      30 for i in range(N_syn):
# ---> 31     train = inhomogeneous_poisson_through_num_points_for_window_one(generate_pink_noise(num_obs = T, mean = mfr) / 1000)
#      32     matrix[i, :] = generate_exponential_current(train)[:T]
#      33 return matrix
#
# File ~/segev/trace.py:8, in inhomogeneous_poisson_through_num_points_for_window_one(lambdas)
#       6 t = np.zeros(len(lambdas))
#       7 for i, lambd in enumerate(lambdas):
# ----> 8     num_points = np.random.poisson(lambd)
#       9     if num_points > 0: t[i] = 1
#      10 return t
#
# File numpy/random/mtrand.pyx:3673, in numpy.random.mtrand.RandomState.poisson()
#
# File numpy/random/mtrand.pyx:114, in numpy.random.mtrand.int64_to_long()
#
# File /opt/anaconda3/envs/simulations/lib/python3.10/site-packages/numpy/core/numeric.py:1855, in isscalar(element)
#    1851 def _frombuffer(buf, dtype, shape, order):
#    1852     return frombuffer(buf, dtype=dtype).reshape(shape, order=order)
# -> 1855 @set_module('numpy')
#    1856 def isscalar(element):
#    1857     """
#    1858     Returns True if the type of `element` is a scalar type.
#    1859
#    (...)
#    1929
#    1930     """
#    1931     return (isinstance(element, generic)
#    1932             or type(element) in ScalarType
#    1933             or isinstance(element, numbers.Number))
#
# KeyboardInterrupt:

# %%
plt.plot(all_train_loss, label = "train loss")
plt.plot(all_test_loss, label = "test loss")
plt.grid()
plt.legend()

# %%
conv_params = list(model.parameters())[0].detach().numpy()[0]
conv_params.shape
# Out:
# (100, 80)

# %%
np.median(conv_params)
# Out:
# 0.18005961

# %%
conv_params
# Out:
# array([[ 0.54131   ,  0.47349748,  0.41318563, ...,  0.44084486,
#          0.49930152,  0.56764746],
#        [ 1.0470155 ,  0.948186  ,  0.8823584 , ...,  0.50625366,
#          0.58276355,  0.6844535 ],
#        [ 0.7273737 ,  0.6418907 ,  0.5769223 , ...,  0.8703752 ,
#          0.9998561 ,  1.1431091 ],
#        ...,
#        [-1.0391077 , -0.90187323, -0.81583726, ..., -1.1479957 ,
#         -1.273328  , -1.364298  ],
#        [-0.41437674, -0.35250315, -0.28700277, ..., -1.4693499 ,
#         -1.6054579 , -1.7222424 ],
#        [-0.5548225 , -0.50515604, -0.4474204 , ..., -2.075593  ,
#         -2.2380078 , -2.3876126 ]], dtype=float32)

# %%
import seaborn as sns
plt.imshow(conv_params, cmap = 'jet')
plt.ylabel("synaptic index");

# %%
exc_params = conv_params[:80]
inh_params = conv_params[80:]
plt.plot(exc_params.mean(axis = 0))
plt.plot(inh_params.mean(axis = 0))

# %%
# Out:
# 24068021
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# [Epoch 0]:
#               train_loss = 7827.56298828125,
#               test_MSE = 5395.0341796875,
#               test_BCE = 577.7308959960938,
#               test_loss = 5972.76513671875,
#               test_acc = 0.99425
#               test_AUC = 0.6075149500934722
# [Epoch 0]:
#               train_loss = 6376.6494140625,
#               test_MSE = 4894.3251953125,
#               test_BCE = 197.52513122558594,
#               test_loss = 5091.85009765625,
#               test_acc = 0.99425
#               test_AUC = 0.5854205157918904

# %%
torch.tensor(spike_times_train).shape
# Out:
# torch.Size([1, 4000])
